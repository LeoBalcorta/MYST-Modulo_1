# %% [markdown]
# <center> <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" align="center" width="960" height="480"/> </center>

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> B.Eng Financial Engineering </font> <br> <br> <br> <br>
#
# <center> <font color= #555555> <font size = 4> Jun 2021 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/if720960/MYST-Modulo_1'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Module 1 </font> <br> <br> <font color= #555555> <font size = 5> Preparation for Data Handling - Part 1  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 1. Introduction </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 2. Install/Load Packages and Depedencies </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# ## <font color= #6B6B6B> 2.2 Python Packages </font> <font color= #555555>

# %% [markdown]
# ## <font color= #6B6B6B> 2.3 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# The following are the file dependencies that are needed to run this notebook:

# %% [markdown]
# - files/ohlc-prices.csv : Historical Open, High, Low, Close 8 Hour Example Prices.

# %% [markdown]
# ## <font color= #6E6E6E> 2.4 Load Packages</font>

# %%
from functions import CloseForm
from functions import finish_code
from functions import consolidate_files
from functions import Files
from functions import choose_files
from functions import Tickers
from functions import stockprices
from functions import tratdatos
from functions import invpasiv
import pandas as pd

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 3. Data  </font>

# %%
# Obtenemos los tickers que se encuentran en todos los archivos
tickers = Tickers()
# Out:
# Files selected
# Closing Window
# Hay 30 Tickers que estan en todos los archivos

# %%
# Con los tickers y yahoofinance obtenemos los precios de las fechas ya establecidas
dfsp = stockprices(tickers)
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
# Obtenemos los pesos de las acciones
dfp_new = tratdatos(dfsp)
dfp_new
# Out:
#            Ticker       Cap       Prices  Titulos
# 0           AC.MX  137000.0    95.383896   1436.0
# 1        ALFAA.MX  118500.0    12.493631   9484.0
# 2        ALSEA.MX  106400.0    39.919998   2665.0
# 3         AMXL.MX  103900.0    14.186114   7324.0
# 4        ASURB.MX   60300.0   303.918610    198.0
# 5      BBAJIOO.MX   43000.0    24.596018   1748.0
# 6       BIMBOA.MX   39600.0    28.224192   1403.0
# 7       BOLSAA.MX   32900.0    35.997463    913.0
# 8     CEMEXCPO.MX   30200.0     6.340000   4763.0
# 9       CUERVO.MX   27500.0    29.032145    947.0
# 10     ELEKTRA.MX   22600.0  1312.390869     17.0
# 11    FEMSAUBD.MX   20600.0   149.901138    137.0
# 12        GAPB.MX   18700.0   197.566406     94.0
# 13    GCARSOA1.MX   18500.0    52.537239    352.0
# 14    GFINBURO.MX   17700.0    21.120001    838.0
# 15    GFNORTEO.MX   17600.0    97.195145    181.0
# 16    GMEXICOB.MX   17300.0    39.167961    441.0
# 17      GRUMAB.MX   16800.0   175.428268     95.0
# 18     KIMBERA.MX   16800.0    32.791058    512.0
# 19        LABB.MX   16700.0    17.986286    928.0
# 20  LIVEPOLC-1.MX   15100.0    85.128685    177.0
# 21     MEGACPO.MX   11600.0    58.929092    196.0
# 22        OMAB.MX    9100.0   110.158867     82.0
# 23       ORBIA.MX    8600.0    35.001041    245.0
# 24     PE&OLES.MX    8300.0   177.357193     46.0
# 25      PINFRA.MX    8100.0   177.046326     45.0
# 26  TLEVISACPO.MX    7900.0    36.249718    217.0
# 27      WALMEX.MX    7400.0    53.523357    138.0

# %% [markdown]
# # <font color= #6B6B6B> 4. Pasiv Invesment  </font>

# %% [markdown]
# <br>

# %%
# Se crea un DataFrame con los datos del portafolio pasivo
invpasiv(dfp_new,dfsp)
# Out:
#               Timestamp         Capital  Rendimiento  Rendimiento_Acumulado
# 0            2020-01-31         1000000          NaN                    NaN
# 0   2020-02-01 00:00:00    957297.05452    -0.042703              -0.042703
# 1   2020-03-01 00:00:00   727727.759768    -0.239810              -0.282513
# 2   2020-04-01 00:00:00   802214.369047     0.102355              -0.180158
# 3   2020-05-01 00:00:00   829536.866316     0.034059              -0.146099
# 4   2020-06-01 00:00:00   887650.297906     0.070055              -0.076044
# 5   2020-07-01 00:00:00   881404.174993    -0.007037              -0.083080
# 6   2020-08-01 00:00:00   894107.718926     0.014413              -0.068668
# 7   2020-09-01 00:00:00   900870.856015     0.007564              -0.061103
# 8   2020-10-01 00:00:00    873883.79101    -0.029957              -0.091060
# 9   2020-11-01 00:00:00   996385.221549     0.140180               0.049120
# 10  2020-12-01 00:00:00  1012048.007305     0.015720               0.064840
# 11  2021-01-01 00:00:00   961810.326313    -0.049640               0.015200
# 12  2021-02-01 00:00:00   979780.628448     0.018684               0.033884
# 13  2021-03-01 00:00:00  1031319.481003     0.052602               0.086487
# 14  2021-04-01 00:00:00  1085047.421658     0.052096               0.138583
# 15  2021-05-01 00:00:00  1138321.211142     0.049098               0.187681
# 16  2021-06-01 00:00:00  1160393.444771     0.019390               0.207071
# 17  2021-07-01 00:00:00  1185930.383791     0.022007               0.229078
# 18  2021-08-01 00:00:00  1229346.053791     0.036609               0.265687
# 19  2021-09-01 00:00:00  1213577.973212    -0.012826               0.252861
# 20  2021-10-01 00:00:00  1237078.066851     0.019364               0.272225
# 21  2021-11-01 00:00:00  1206355.452266    -0.024835               0.247390
# 22  2021-12-01 00:00:00  1272414.233309     0.054759               0.302149
# 23  2022-01-01 00:00:00  1254912.125326    -0.013755               0.288394
# 24  2022-02-01 00:00:00  1301109.375736     0.036813               0.325208
# 25  2022-03-01 00:00:00  1358205.815574     0.043883               0.369090
# 26  2022-04-01 00:00:00  1273327.984951    -0.062493               0.306598
# 27  2022-05-01 00:00:00  1291870.176592     0.014562               0.321160
# 28  2022-06-01 00:00:00  1225110.632063    -0.051677               0.269483
# 29  2022-07-01 00:00:00  1266673.208122     0.033926               0.303409

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> References </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>
