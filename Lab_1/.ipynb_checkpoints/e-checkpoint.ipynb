# %%
from PyQt5.QtWidgets import *
import pandas as pd
import xlwings as xw
import sys
import yfinance as yf
import numpy as np

# %%
from functions import CloseForm
from functions import finish_code
from functions import consolidate_files
from functions import Files
from functions import choose_files
from functions import Tickers
from functions import stockprices
from functions import tratdatos
from functions import invpasiv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32584/327268158.py in <module>
# ----> 1 from functions import CloseForm
#       2 from functions import finish_code
#       3 from functions import consolidate_files
#       4 from functions import Files
#       5 from functions import choose_files
#
# ~\Documents\ITESO\9no Semestre\MYST\Modulo_1\Lab_1\functions.py in <module>
#       1
# ----> 2 class CloseForm(QWidget):
#       3     def __init__(self, name = 'CloseForm'):
#       4         super(CloseForm,self).__init__()
#       5         self.setWindowTitle(name)
#
# NameError: name 'QWidget' is not defined

# %%
# Obtenemos los tickers que se encuentran en todos los archivos
tickers = Tickers()
# Out:
# Files selected
# Closing Window
# Hay 30 Tickers que estan en todos los archivos

# %%
# Con los tickers y yahoofinance obtenemos los precios de las fechas ya establecidas
dfsp = stockprices(tickers)
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
# Obtenemos los pesos de las acciones
dfp_new = tratdatos(dfsp)
# Out:
# C:\Users\PerezBL\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Se crea un DataFrame con los datos del portafolio pasivo
invpasiv(dfp_new,dfsp)
# Out:
#               Timestamp         Capital  Rendimiento  Rendimiento_Acumulado
# 0            2020-01-31         1000000          NaN                    NaN
# 0   2020-02-01 00:00:00   957297.032131    -0.042703              -0.042703
# 1   2020-03-01 00:00:00   727727.773098    -0.239810              -0.282513
# 2   2020-04-01 00:00:00   802214.399314     0.102355              -0.180158
# 3   2020-05-01 00:00:00   829536.871084     0.034059              -0.146099
# 4   2020-06-01 00:00:00   887650.283052     0.070055              -0.076044
# 5   2020-07-01 00:00:00   881404.181047    -0.007037              -0.083080
# 6   2020-08-01 00:00:00   894107.729619     0.014413              -0.068668
# 7   2020-09-01 00:00:00   900870.845693     0.007564              -0.061103
# 8   2020-10-01 00:00:00   873883.797148    -0.029957              -0.091060
# 9   2020-11-01 00:00:00    996385.22692     0.140180               0.049120
# ...
